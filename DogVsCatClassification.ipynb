# %%
import os
import cv2
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
def load_images(folder):
    images = []
    for filename in os.listdir(folder):
        img = cv2.imread(os.path.join(folder,filename))
        print(os.path.join(filename,folder))
        images.append({'filename':filename,'image':img})
    return images

# %%
images = load_images('./train/train/')
# Out:
# cat.0.jpg\./train/train/
# cat.1.jpg\./train/train/
# cat.10.jpg\./train/train/
# cat.100.jpg\./train/train/
# cat.1000.jpg\./train/train/
# cat.10000.jpg\./train/train/
# cat.10001.jpg\./train/train/
# cat.10002.jpg\./train/train/
# cat.10003.jpg\./train/train/
# cat.10004.jpg\./train/train/
# cat.10005.jpg\./train/train/
# cat.10006.jpg\./train/train/
# cat.10007.jpg\./train/train/
# cat.10008.jpg\./train/train/
# cat.10009.jpg\./train/train/
# cat.1001.jpg\./train/train/
# cat.10010.jpg\./train/train/
# cat.10011.jpg\./train/train/
# cat.10012.jpg\./train/train/
# cat.10013.jpg\./train/train/
# cat.10014.jpg\./train/train/
# cat.10015.jpg\./train/train/
# cat.10016.jpg\./train/train/
# cat.10017.jpg\./train/train/
# cat.10018.jpg\./train/train/
# cat.10019.jpg\./train/train/
# cat.1002.jpg\./train/train/
# cat.10020.jpg\./train/train/
# cat.10021.jpg\./train/train/
# cat.10022.jpg\./train/train/
# cat.10023.jpg\./train/train/
# cat.10024.jpg\./train/train/
# ...

# %%
imageDataFrame = pd.DataFrame(images)

# %%
imageDataFrame['category'] = imageDataFrame['filename'].apply(lambda x: 'Cat' if 'cat' in x else 'Dog')

# %%
imageDataFrame.head()
imageDataFrameFinal = imageDataFrame.drop(columns=['filename'],axis=1)

# %%
X = imageDataFrameFinal['image'].values
Y = imageDataFrameFinal['category'].values

# %%
# Out:
# array(['Cat', 'Cat', 'Cat', ..., 'Dog', 'Dog', 'Dog'], dtype=object)

# %%
X_train, X_test, Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
# Out:
# array([array([[[18, 18, 24],
#                [17, 17, 23],
#                [16, 16, 22],
#                ...,
#                [23, 35, 59],
#                [23, 36, 58],
#                [21, 34, 56]],
#
#               [[18, 18, 24],
#                [17, 17, 23],
#                [16, 16, 22],
#                ...,
#                [24, 37, 59],
#                [23, 36, 58],
#                [22, 35, 57]],
#
#               [[18, 18, 24],
#                [18, 18, 24],
#                [16, 16, 22],
#                ...,
#                [23, 37, 59],
#                [22, 36, 58],
#                [21, 35, 57]],
#
#               ...,
#
#               [[48, 64, 87],
#                [47, 63, 86],
#                [45, 61, 84],
#                ...,
#                [83, 87, 98],
#                [82, 86, 97],
#                [83, 85, 96]],
#
#               [[43, 59, 82],
#                [44, 60, 83],
#                [45, 61, 84],
#                ...,
# ...
